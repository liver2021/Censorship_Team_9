# %%
import pandas as pd
import matplotlib.pyplot as plt 
import Team_9 as tm
df = pd.read_csv('/Users/macintosh/OONI_Project/ooni_data_DE_GMB_2021.csv')
df_1 = pd.read_csv('/Users/macintosh/OONI_Project/ooni_data_FR_GMB_2021.csv')
x = pd.concat([df,df_1])
df_1 = pd.read_csv('/Users/macintosh/OONI_Project/ooni_data_FR_GMB_2021.csv')

# %%
tm.blocking(df,"Germany",2023)
# Out:
#     year  month  http_count  http_diff_count  dns_count  tcp_ip_count  \
# 0   2021      1          12               21          2             1
# 1   2021      2           5               10          6             2
# 2   2021      3           6               64        169             4
# 3   2021      4          11               62        205             6
# 4   2021      5           6               29         36             4
# 5   2021      6           0               50         35             0
# 6   2021      7           2              110         63             2
# 7   2021      8           8               99         31             5
# 8   2021      9          32              209         30            10
# 9   2021     10          84              809        598             9
# 10  2021     11          95             1403       1304            36
# 11  2021     12          78             1427       1085            54
#
#     NaN_count
# 0        1071
# 1         775
# ...

# %%
tm.do_plots(df,"Germany",2023)
# Out:
#     year  month  anomaly_count  confirmed_count  failure_count  valid_count
# 0   2021      1             36                0            719          354
# 1   2021      2             23                0            473          303
# 2   2021      3            243                0            162         1513
# 3   2021      4            284                0             13         1104
# 4   2021      5             75                0              5          661
# 5   2021      6             85                0             15         1122
# 6   2021      7            177                0             41         1958
# 7   2021      8            143                0             18         1917
# 8   2021      9            281                0             17         4638
# 9   2021     10           1500                3             60        19381
# 10  2021     11           2838                0            656        33295
# ...

# %%
df.head(1)
# Out:
#    anomaly  confirmed  failure                       input  \
# 0     True      False    False  http://www.pokerstars.com/
#
#                                      measurement_uid  \
# 0  20210101210459.799421_DE_webconnectivity_9d385...
#
#                                      measurement_url probe_asn probe_cc  \
# 0  https://api.ooni.io/api/v1/raw_measurement?mea...    AS6805       DE
#
#                                            report_id         test_name  \
# 0  20210101T202626Z_webconnectivity_DE_6805_n1_HV...  web_connectivity
#
#   blocking_type  year  month  day  valid  http-failure    NaN  http-diff  \
# 0  http-failure  2021      1    1  False          True  False      False
#
#      dns  tcp_ip
# 0  False   False

# %%
df.shape
# Out:
# (114570, 20)

# %%
df['input'].nunique()
df['input'].value_counts()[:30]
# Out:
# input
# http://www.blackjackinfo.com/          4786
# http://www.sportsinteraction.com/      4783
# http://www.sportingbet.com/            4782
# http://www.spinpalace.com/             4777
# http://www.globet.com/                 4776
# https://www.gambling.com/              4776
# http://www.888casino.com/              4775
# http://www.partypoker.com/             4773
# http://www.luckynugget.com/            4773
# http://www.royalvegas.com/             4773
# http://www.slotland.com/               4773
# http://onlybingo.com/                  4772
# http://www.europacasino.com/           4768
# http://www.pokerstars.com/             4765
# http://www.betfair.com/                4764
# http://www.monacogoldcasino.com/       4764
# https://www.onlinegambling.com/        4764
# https://www.partypoker.net/            4763
# http://www.goldenrivieracasino.com/    4759
# http://www.4online-gambling.com/       4756
# http://www.poker.com/                  4756
# ...
